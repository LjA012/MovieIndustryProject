# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
imdb_name_basics = pd.read_csv("zippedData/imdb.name.basics.csv")
imdb_title_akas = pd.read_csv("zippedData/imdb.title.akas.csv")
imdb_title_basics = pd.read_csv("zippedData/imdb.title.basics.csv")
imdb_title_crew = pd.read_csv("zippedData/imdb.title.crew.csv")
imdb_title_principals = pd.read_csv("zippedData/imdb.title.principals.csv")
imdb_title_ratings = pd.read_csv("zippedData/imdb.title.ratings.csv")

# %%
bom = pd.read_csv("zippedData/bom.movie_gross.csv")

# %%
rt_movie_info = pd.read_csv("zippedData/rt.movie_info.tsv",sep="\t")
rt_reviews = pd.read_csv("zippedData/rt.reviews.tsv", sep="\t", encoding = "ISO-8859-1")

# %%
tmdb = pd.read_csv("zippedData/tmdb.movies.csv")

# %%
tn_movie_budgets = pd.read_csv("zippedData/tn.movie_budgets.csv")

# %%
tn_movie_budgets.release_date = pd.to_datetime(tn_movie_budgets.release_date)

# %%
### Data Cleaning ###

#First taking recent movies from 2010 to 2018 in the tn dataframe
tn_movie_budgets = tn_movie_budgets[(tn_movie_budgets.release_date.dt.year > 2009) & (tn_movie_budgets.release_date.dt.year<2019)]
tn_movie_budgets.shape
# Out:
# (2124, 6)

# %%
#Change budget and gross strings into integers
tn_movie_budgets['worldwide_gross'] = tn_movie_budgets['worldwide_gross'].str.replace(',', '').str.replace('$','').astype(int)
tn_movie_budgets['production_budget'] = tn_movie_budgets['production_budget'].str.replace(',', '').str.replace('$','').astype(int)
tn_movie_budgets['domestic_gross'] = tn_movie_budgets['domestic_gross'].str.replace(',', '').str.replace('$','').astype(int)

# %%
tn_movie_budgets["worldwide_gross_budget_ratio"] = tn_movie_budgets['worldwide_gross'] / tn_movie_budgets['production_budget']

# %%
tn_movie_budgets["Earnings"] = tn_movie_budgets["worldwide_gross"] - tn_movie_budgets["production_budget"]

# %%
tn_movie_budgets.release_date = pd.to_datetime(tn_movie_budgets.release_date)

tn_movie_budgets["year"] = tn_movie_budgets.release_date.dt.year
imdb_title_ratings_basics = pd.merge(imdb_title_ratings, imdb_title_basics, left_on='tconst', right_on='tconst')

# %%
master_df = pd.merge(tn_movie_budgets, imdb_title_ratings_basics, left_on=["movie","year" ], right_on=["primary_title", "start_year"], how='inner')

# %%
master_df.rename(str.title, axis='columns', inplace=True)

# %%
master_df.drop(columns=['Primary_Title', 'Original_Title', 'Start_Year', 'Id', 'Release_Date', 'Tconst'], inplace=True)

# %%
master_df.head()
# Out:
#                                          Movie  Production_Budget  \
# 0  Pirates of the Caribbean: On Stranger Tides          410600000
# 1                      Avengers: Age of Ultron          330600000
# 2                       Avengers: Infinity War          300000000
# 3                               Justice League          300000000
# 4                                      Spectre          300000000
#
#    Domestic_Gross  Worldwide_Gross  Worldwide_Gross_Budget_Ratio    Earnings  \
# 0       241063875       1045663875                      2.546673   635063875
# 1       459005868       1403013963                      4.243841  1072413963
# 103        1019429616                      6.796197  869429616  2016
# 885           1844228                      0.115264  -14155772  2013
# 249         345033359                      4.059216  260033359  2017
#
#       Averagerating  Numvotes  Runtime_Minutes                      Genres
# 1337            3.0      3092            101.0          Crime,Drama,Horror
# 1151            7.2    260383            103.0        Drama,Horror,Mystery
# 987             6.7      1114            111.0                       Drama
# 542             6.6     50155            130.0        Action,Drama,History
# 767             8.1    577301            134.0     Biography,Drama,History
# 847             7.6    323949             94.0   Adventure,Biography,Drama
# 1220            6.3     29550             93.0             Horror,Thriller
# 328             6.7    182025            109.0         Action,Comedy,Crime
# 448             7.2    477771            109.0         Action,Comedy,Crime
# 385             7.0    319504            112.0         Action,Comedy,Crime
# 1361            6.5      1567             98.0          Drama,Family,Sport
# 662             6.2     81681            117.0       Action,Drama,Thriller
# 661             6.1     87254             83.0         Action,Comedy,Crime
# 181             6.2    262978            102.0          Action,Fantasy,War
# 1330            5.1     15055            102.0             Horror,Thriller
# 593             7.5     77703            128.0       Biography,Drama,Sport
# 73              6.3    135754            128.0      Action,Adventure,Drama
# 986             5.6     13089            113.0            Action,Drama,War
# 1048            6.6      1739            110.0                       Drama
# 1087            7.7    300475            100.0        Comedy,Drama,Romance
# 1271            7.0      1190             80.0                 Documentary
# 1177            4.8      3105            121.0                       Drama
# 654             5.5     33056            104.0            Adventure,Comedy
# 1045            7.2     14602             98.0               Drama,Romance
# 1046            6.6      1519            110.0                       Drama
# 805             6.4     93259             99.0     Biography,Drama,Romance
# 1373            5.4       279            111.0                       Drama
# 1443            6.8     46280             92.0       Drama,Fantasy,Romance
# 225             5.3    188383             98.0             Action,Thriller
# 1265            5.1     40308             86.0              Comedy,Fantasy
# ...             ...       ...              ...                         ...
# 1198            3.3      1576             87.0                      Comedy
# 858             5.3      7312             91.0       Action,Fantasy,Horror
# 994             7.3     48501            109.0     Biography,Drama,History
# 833             6.4      5915            121.0                       Drama
# 760             8.0    111632            113.0                Drama,Family
# 101             7.5    487527            141.0    Action,Adventure,Fantasy
# 943             6.5      6070            123.0                 Drama,Sport
# 47              7.0    553751            116.0     Action,Adventure,Horror
# 112             5.7    172330             99.0    Action,Adventure,Fantasy
# 86              7.7    344496            101.0  Adventure,Animation,Comedy
# 62              7.0    356556            144.0     Action,Adventure,Sci-Fi
# 37              8.0    620079            132.0     Action,Adventure,Sci-Fi
# 94              7.7    608930            131.0     Action,Adventure,Sci-Fi
# 1085            7.1     33971            160.0        Comedy,Drama,Musical
# 1191            4.3     10483             88.0       Action,Comedy,Fantasy
# 261             4.6     18934             80.0  Adventure,Animation,Comedy
# 784             5.8     46690            105.0       Comedy,Family,Romance
# 913             6.3     41608             98.0        Comedy,Drama,Romance
# 975             6.3     74071             94.0                Comedy,Drama
# 410             5.5     92940            102.0    Adventure,Comedy,Fantasy
# 945             7.3     64418            124.0          Comedy,Drama,Music
# 816             5.8      6010             83.0  Adventure,Animation,Comedy
# 379             7.4    251072            157.0              Drama,Thriller
# 1204            5.8      6120            112.0              Drama,Thriller
# 1371            3.5      2372             93.0        Action,Comedy,Horror
# 265             5.2     52396            102.0       Comedy,Family,Romance
# 407             4.7     59914            101.0                      Comedy
# 103             8.0    383446            108.0  Adventure,Animation,Comedy
# 885             6.7     16607            110.0        Crime,Drama,Thriller
# 249             5.2     77976            107.0   Action,Adventure,Thriller
#
# [1465 rows x 11 columns]

# %%
master_df["Genre_1"] = master_df.Genres.str.split(',', expand=True)[0]
master_df["Genre_2"] = master_df.Genres.str.split(',', expand=True)[1]
master_df["Genre_3"] = master_df.Genres.str.split(',', expand=True)[2]
master_df = master_df.drop(columns = ["Genres"])
master_df.head()
# Out:
#                                          Movie  Production_Budget  \
# 0  Pirates of the Caribbean: On Stranger Tides          410600000
# 1                      Avengers: Age of Ultron          330600000
# 2                       Avengers: Infinity War          300000000
# 3                               Justice League          300000000
# 4                                      Spectre          300000000
#
#    Domestic_Gross  Worldwide_Gross  Worldwide_Gross_Budget_Ratio    Earnings  \
# 0       241063875       1045663875                      2.546673   635063875
# 1       459005868       1403013963                      4.243841  1072413963
# 2       678815482       2048134200                      6.827114  1748134200
# 3       229024295        655945209                      2.186484   355945209
# 4       200074175        879620923                      2.932070   579620923
#
#    Year  Averagerating  Numvotes  Runtime_Minutes Genre_1    Genre_2   Genre_3
# 0  2011            6.6    447624            136.0  Action  Adventure   Fantasy
# 1  2015            7.3    665594            141.0  Action  Adventure    Sci-Fi
# 2  2018            8.5    670926            149.0  Action  Adventure    Sci-Fi
# 3  2017            6.5    329135            120.0  Action  Adventure   Fantasy
# 4  2015            6.8    352504            148.0  Action  Adventure  Thriller

# %%
genre_set = set(master_df["Genre_1"].unique())
genre_set.update(master_df["Genre_2"].unique())

genre_set.update(master_df["Genre_3"].unique())
#genre_set.pop()
#genre_set.remove(None)
genre_dict = { i : 0 for i in genre_set }

# %%
temp = master_df[["Genre_1", "Genre_2", "Genre_3", "Averagerating"]]
for i,j in temp.iterrows():
    genre_dict[j[0]]+=j[3]
    genre_dict[j[1]]+=j[3]
    genre_dict[j[2]]+=j[3]

# %%
for key, value in genre_dict.items():
    print(key, value)
# Out:
# nan 41.699999999999996
# Fantasy 727.7999999999997
# War 111.69999999999999
# Family 557.4
# Sci-Fi 818.3
# Action 2725.5999999999985
# Drama 4665.399999999996
# Sport 234.29999999999998
# Adventure 2170.4999999999995
# Romance 1167.0999999999995
# History 264.1000000000001
# Mystery 725.8000000000002
# Comedy 3128.3000000000025
# Crime 1465.3
# Biography 900.5000000000003
# Music 297.99999999999994
# Horror 957.4000000000007
# Musical 54.699999999999996
# Thriller 1538.6000000000006
# Western 69.5
# Animation 634.1000000000004
# None 4118.000000000001
# Documentary 252.0
